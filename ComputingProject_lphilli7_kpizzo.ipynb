# %%
#Names: Luke Phillipp and Kenny Pizzo
#NetIDS: lphilli7 and kpizzo
#Project ID: 2-30

# %% [markdown]
# # Code Running Instructions
# - This is the complete code for our project, including our data writing, dataframe creation, data cleaning and manipulation, visulization, and embedding in html code
# - Upload these files
#   - Consumer-Price-Index.csv
#   - FedFunds.csv
#   - Home-Price-Index.csv
#   - Mortgage.csv
#   - Home Prices by State.csv
# - Go to runtime and 'run all'

# %%
ls
# Out:
#  bar.html          Consumer-Price-Index.csv   Home-Price-Index.csv        inf_hp_viz.html
#  box.html          FedFunds.csv              'Home Prices by State.csv'   Mortgage.csv
#  choropleth.html   FF_30YR.html               hp_time.html                sample_data/

# %%
import pandas as pd
import plotly.express as px
import plotly.io as pio

# %% [markdown]
# # Economic Indicators DF creation and plotting

# %%
# Read all CSV files into separate DataFrames
df_consumer_price_index = pd.read_csv('Consumer-Price-Index.csv')
df_fed_funds = pd.read_csv('FedFunds.csv')
df_home_price_index = pd.read_csv('Home-Price-Index.csv')
df_mortgage = pd.read_csv('Mortgage.csv')
\
# Merge DataFrames on the 'DATE' column
dfs = [
    df_consumer_price_index, df_fed_funds,
    df_home_price_index, df_mortgage
    ]

# Merging all DataFrames on the 'DATE' column
merged_df = dfs[0]

for df in dfs[1:]:
    merged_df = pd.merge(merged_df, df, on='DATE', how='outer')


df_trimmed = merged_df.drop(df.index[:480])

# Display the merged DataFrame
print(df_trimmed)
# Out:
#             DATE  CPIAUCSL  FEDFUNDS  CSUSHPISA  MORTGAGE30US
# 480   1987-01-01     111.4      6.43     63.964           NaN
# 481   1987-02-01     111.8      6.10     64.424           NaN
# 482   1987-03-01     112.2      6.13     64.736           NaN
# 483   1987-04-01     112.7      6.37     65.132           NaN
# 484   1987-05-01     113.0      6.85     65.563         10.47
# ...          ...       ...       ...        ...           ...
# 3576  2023-09-28       NaN       NaN        NaN          7.31
# 3577  2023-10-05       NaN       NaN        NaN          7.49
# 3578  2023-10-12       NaN       NaN        NaN          7.57
# 3579  2023-10-19       NaN       NaN        NaN          7.63
# 3580  2023-10-26       NaN       NaN        NaN          7.79
#
# [3101 rows x 5 columns]

# %%
fig1 = px.line(df_trimmed, x='DATE', y=['CPIAUCSL','CSUSHPISA'],
              title='Inflation vs. Home Prices',
              range_x=['1987-01-01','2023-10-26'],
              range_y=[0,350])

fig1.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="d051856c-3032-4d2e-a98b-71814740560a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d051856c-3032-4d2e-a98b-71814740560a")) {                    Plotly.newPlot(                        "d051856c-3032-4d2e-a98b-71814740560a",                        [{"hovertemplate":"variable=CPIAUCSL\u003cbr\u003eDATE=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"CPIAUCSL","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"CPIAUCSL","showlegend":true,"x":["1987-01-01","1987-02-01","1987-03-01","1987-04-01","1987-05-01","1987-06-01","1987-07-01","1987-08-01","1987-09-01","1987-10-01","1987-11-01","1987-12-01","1988-01-01","1988-02-01","1988-03-01","1988-04-01","1988-05-01","1988-06-01","1988-07-01","1988-08-01","1988-09-01","1988-10-01","1988-11-01","1988-12-01","1989-01-01","1989-02-01","1989-03-01","1989-04-01","1989-05-01","1989-06-01","1989-07-01","1989-08-01","1989-09-01","1989-10-01","1989-11-01","1989-12-01","1990-01-01","1990-02-01","1990-03-01","1990-04-01","1990-05-01","1990-06-01","1990-07-01","1990-08-01","1990-09-01","1990-10-01","1990-11-01","1990-12-01","1991-01-01","1991-02-01","1991-03-01","1991-04-01","1
10-01","1994-11-01","1994-12-01","1995-01-01","1995-02-01","1995-03-01","1995-04-01","1995-05-01","1995-06-01","1995-07-01","1995-08-01","1995-09-01","1995-10-01","1995-11-01","1995-12-01","1996-01-01","1996-02-01","1996-03-01","1996-04-01","1996-05-01","1996-06-01","1996-07-01","1996-08-01","1996-09-01","1996-10-01","1996-11-01","1996-12-01","1997-01-01","1997-02-01","1997-03-01","1997-04-01","1997-05-01","1997-06-01","1997-07-01","1997-08-01","1997-09-01","1997-10-01","1997-11-01","1997-12-01","1998-01-01","1998-02-01","1998-03-01","1998-04-01","1998-05-01","1998-06-01","1998-07-01","1998-08-01","1998-09-01","1998-10-01","1998-11-01","1998-12-01","1999-01-01","1999-02-01","1999-03-01","1999-04-01","1999-05-01","1999-06-01","1999-07-01","1999-08-01","1999-09-01","1999-10-01","1999-11-01","1999-12-01","2000-01-01","2000-02-01","2000-03-01","2000-04-01","2000-05-01","2000-06-01","2000-07-01","2000-08-01","2000-09-01","2000-10-01","2000-11-01","2000-12-01","2001-01-01","2001-02-01","2001-03-01","2001-04-01","2001-05-01","2001-06-01","2001-07-01","2001-08-01","2001-09-01","2001-10-01","2001-11-01","2001-12-01","2002-01-01","2002-02-01","2002-03-01","2002-04-01","2002-05-01","2002-06-01","2002-07-01","2002-08-01","2002-09-01","2002-10-01","2002-11-01","2002-12-01","2003-01-01","2003-02-01","2003-03-01","2003-04-01","2003-05-01","2003-06-01","2003-07-01","2003-08-01","2003-09-01","2003-10-01","2003-11-01","2003-12-01","2004-01-01","2004-02-01","2004-03-01","2004-04-01","2004-05-01","2004-06-01","2004-07-01","2004-08-01","2004-09-01","2004-10-01","2004-11-01","2004-12-01","2005-01-01","2005-02-01","2005-03-01","2005-04-01","2005-05-01","2005-06-01","2005-07-01","2005-08-01","2005-09-01","2005-10-01","2005-11-01","2005-12-01","2006-01-01","2006-02-01","2006-03-01","2006-04-01","2006-05-01","2006-06-01","2006-07-01","2006-08-01","2006-09-01","2006-10-01","2006-11-01","2006-12-01","2007-01-01","2007-02-01","2 ...

# %%
df_consumer_price_index = pd.read_csv('Consumer-Price-Index.csv')
#print(df_consumer_price_index)

df_fed_funds = pd.read_csv('FedFunds.csv')
#print(df_fed_funds)

df_home_price_index = pd.read_csv('Home-Price-Index.csv')
#print(df_home_price_index)

df_mortgage = pd.read_csv('Mortgage.csv')
#print(df_mortgage)

# %% [markdown]
# # Economic Indicators Embedding

# %%
fh = open('inf_hp_viz.html', 'w')
fh.close()

# %%
pio.write_html(fig1, file='inf_hp_viz.html',
               auto_open=True,
               full_html=False)

# %%
fh = open('FF_30YR.html', 'w')
fh.close()

# %%
pio.write_html(fig2, file='FF_30YR.html',
               auto_open=True,
               full_html=False)

# %% [markdown]
# # State Home Prices Dataframe creation and plotting

# %%
# Creating the dataframe
df_hp_raw = pd.read_csv('Home Prices by State.csv')

df_hp_raw['Date'] = pd.to_datetime(df_hp_raw['Date'])
df_home_price = df_hp_raw.melt(id_vars='Date', var_name='State', value_name='Home_Price')

state_abbr = {
    'Alabama': 'AL', 'Alaska': 'AK', 'Arizona': 'AZ', 'Arkansas': 'AR', 'California': 'CA',
    'Colorado': 'CO', 'Connecticut': 'CT', 'Delaware': 'DE', 'Florida': 'FL', 'Georgia': 'GA',
    'Hawaii': 'HI', 'Idaho': 'ID', 'Illinois': 'IL', 'Indiana': 'IN', 'Iowa': 'IA',
    'Kansas': 'KS', 'Kentucky': 'KY', 'Louisiana': 'LA', 'Maine': 'ME', 'Maryland': 'MD',
    'Massachusetts': 'MA', 'Michigan': 'MI', 'Minnesota': 'MN', 'Mississippi': 'MS', 'Missouri': 'MO',
    'Montana': 'MT', 'Nebraska': 'NE', 'Nevada': 'NV', 'New Hampshire': 'NH', 'New Jersey': 'NJ',
    'New Mexico': 'NM', 'New York': 'NY', 'North Carolina': 'NC', 'North Dakota': 'ND', 'Ohio': 'OH',
    'Oklahoma': 'OK', 'Oregon': 'OR', 'Pennsylvania': 'PA', 'Rhode Island': 'RI', 'South Carolina': 'SC',
    'South Dakota': 'SD', 'Tennessee': 'TN', 'Texas': 'TX', 'Utah': 'UT', 'Vermont': 'VT',
    'Virginia': 'VA', 'Washington': 'WA', 'West Virginia': 'WV', 'Wisconsin': 'WI', 'Wyoming': 'WY'
}

df_home_price['State'] = df_home_price['State'].replace(state_abbr)


print(df_home_price)
print(df_home_price.dtypes)
# Out:
#            Date State   Home_Price
# 0    2019-01-31    CA  536558.0937
# 1    2019-02-28    CA  534955.2156
# 2    2019-03-31    CA  533139.1600
# 3    2019-04-30    CA  532096.8371
# 4    2019-05-31    CA  531472.8461
# ...         ...   ...          ...
# 2953 2023-06-30    WY  332954.3105
# 2954 2023-07-31    WY  334631.7940
# 2955 2023-08-31    WY  336277.2311
# 2956 2023-09-30    WY  337610.2837
# 2957 2023-10-31    WY  338887.5302
#
# [2958 rows x 3 columns]
# Date          datetime64[ns]
# State                 object
# Home_Price           float64
# dtype: object

# %%
# Creating Choropleth
# Plot figure
fig5 = px.choropleth(df_home_price,
                    locations='State',
                    locationmode='USA-states',
                    color='Home_Price',
                    hover_name='State',
                    scope='usa',
                    range_color=(150000,800000)
                   )
fig5.update_layout(title='Average Home Price over Past 5 Years')
fig5.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="c14dd2ec-908f-4284-9292-268a43caece6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c14dd2ec-908f-4284-9292-268a43caece6")) {                    Plotly.newPlot(                        "c14dd2ec-908f-4284-9292-268a43caece6",                        [{"coloraxis":"coloraxis","geo":"geo","hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eState=%{location}\u003cbr\u003eHome_Price=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["CA","CA","CA","CA","CA","CA","CA","CA","CA","CA","CA","CA","CA","CA","CA","CA","CA","CA","CA","CA","CA","CA","CA","CA","CA","CA","CA","CA","CA","CA","CA","CA","CA","CA","CA","CA","CA","CA","CA","CA","CA","CA","CA","CA","CA","CA","CA","CA","CA","CA","CA","CA","CA","CA","CA","CA","CA","CA","TX","TX","TX","TX","TX","TX","TX","TX","TX","TX","TX","TX","TX","TX","TX","TX","TX","TX","TX","TX","TX","TX","TX","TX","TX","TX","TX","TX","TX","TX","TX","TX","TX","TX","TX","TX","TX","TX","TX","TX","TX","TX","TX","TX","TX","TX","TX","TX","TX","TX","TX","TX","TX","TX","TX","TX","TX","TX","FL","FL","FL","FL","FL","FL","FL","FL","FL","FL","FL","FL","FL","FL","FL","FL","FL","FL","FL","FL","FL","FL","FL","FL","FL","FL","FL","FL","FL","FL","FL","FL","FL","FL","FL","FL","FL","FL","FL","FL","FL","FL","FL","FL","FL","FL","FL","FL","FL","FL","FL","FL","FL","FL","FL","FL","FL","FL","NY","NY","NY","NY","NY","NY","NY","NY","NY","NY","NY","NY","NY","NY","NY","NY","NY","NY","NY","NY","NY","NY","NY","NY","NY","NY","NY","NY","NY","NY","NY","NY","NY","NY","NY","NY","NY","NY","NY","NY","NY","NY","NY","NY","NY","NY","NY","NY","NY","NY","NY","NY","NY","NY","NY","NY","NY","NY","PA","PA","PA","PA","PA","PA","PA","PA","PA","PA","PA","PA","PA","PA","PA","PA","PA","PA","PA","PA","PA","PA","PA","PA","PA","PA","PA","PA","PA","PA","PA","PA","PA","PA","PA","PA","PA","PA","PA","PA","PA","PA","PA","PA","PA","PA","PA","PA","PA","PA","PA","PA","PA","PA","PA","PA","PA","PA","IL","IL","IL","IL","IL","IL","IL","IL","IL","IL","IL","IL","IL","IL","IL","IL","IL","IL","IL","IL","IL","IL","IL","IL","IL","IL","IL","IL","IL","IL","IL","IL","IL","IL","IL","IL","IL","IL","IL","IL","IL","IL","IL","IL","IL","IL","IL","IL","IL","IL","IL","IL","IL","IL","IL","IL","IL","IL","OH","OH","OH","OH","OH","OH","OH","OH","OH","OH","OH","OH","OH","OH","OH","OH","OH","OH","OH","OH","OH","OH","OH","OH","OH","OH","OH","OH","OH","OH","OH","OH","OH","OH","OH","OH","OH","OH","OH","OH","OH","OH","OH","OH","OH","OH","OH","OH","OH","OH","OH","OH","OH","OH","OH","OH","OH","OH","GA","GA","GA","GA","GA","GA","GA","GA","GA","GA","GA","GA","GA","GA","GA","GA","GA","GA","GA","GA","GA","GA","GA","GA","GA","GA","GA","GA","GA","GA","GA","GA","GA","GA","GA","GA","GA","GA","GA","GA","GA","GA","GA","GA","GA","GA","GA","GA","GA","GA","GA","GA","GA","GA","GA","GA","GA","GA","NC","NC","NC","NC","NC","NC","NC","NC","NC","NC","NC","NC","NC","NC","NC","NC","NC","NC","NC","NC","NC","NC","NC","NC","NC","NC","NC","NC","NC","NC","NC","NC","NC","NC","NC","NC","NC","NC","NC","NC","NC","NC","NC","NC","NC","NC","NC","NC","NC","NC","NC","NC","NC","NC","NC","NC","NC","NC","MI","MI","MI","MI","MI","MI","MI","MI","MI","MI","MI","MI","MI","MI","MI","MI","MI","MI","MI","MI","MI","MI","MI","MI","MI","MI","MI","MI","MI","MI","MI","MI","MI","MI","MI","MI","MI","MI","MI","MI","MI","MI","MI","MI","MI","MI","MI","MI","MI","MI","MI","MI","MI","MI","MI","MI","MI","MI","NJ","NJ","NJ","NJ","NJ","NJ","NJ","NJ","NJ","NJ","NJ","NJ","NJ","NJ","NJ","NJ","NJ","NJ","NJ","NJ","NJ","NJ","NJ","NJ","NJ","NJ","NJ","NJ","NJ","NJ","NJ","NJ","NJ","NJ","NJ","NJ","NJ","NJ","NJ","NJ","NJ","NJ","NJ","NJ","NJ","NJ","NJ","NJ","NJ","NJ","NJ","NJ","NJ","NJ","NJ","NJ","NJ","NJ","VA","VA","VA","VA" ...

# %%
avg_prices = df_home_price.groupby('State')['Home_Price'].mean().reset_index()
avg_prices_sorted = avg_prices.sort_values(by='Home_Price')

fig6 = px.bar(avg_prices_sorted, x='State', y='Home_Price', color='State', title='Average Home Prices by State')
fig6.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="5e5538c6-5111-42e9-8fb6-e5f90fdac117" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5e5538c6-5111-42e9-8fb6-e5f90fdac117")) {                    Plotly.newPlot(                        "5e5538c6-5111-42e9-8fb6-e5f90fdac117",                        [{"alignmentgroup":"True","hovertemplate":"State=%{x}\u003cbr\u003eHome_Price=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"WV","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"WV","offsetgroup":"WV","orientation":"v","showlegend":true,"textposition":"auto","x":["WV"],"xaxis":"x","y":[136459.63896896553],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"State=%{x}\u003cbr\u003eHome_Price=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"MS","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"MS","offsetgroup":"MS","orientation":"v","showlegend":true,"textposition":"auto","x":["MS"],"xaxis":"x","y":[156474.3583586207],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"State=%{x}\u003cbr\u003eHome_Price=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"OK","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"OK","offsetgroup":"OK","orientation":"v","showlegend":true,"textposition":"auto","x":["OK"],"xaxis":"x","y":[164738.34320172414],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"State=%{x}\u003cbr\u003eHome_Price=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"KY","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"KY","offsetgroup":"KY","orientation":"v","showlegend":true,"textposition":"auto","x":["KY"],"xaxis":"x","y":[165947.60447586206],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"State=%{x}\u003cbr\u003eHome_Price=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"AR","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"AR","offsetgroup":"AR","orientation":"v","showlegend":true,"textposition":"auto","x":["AR"],"xaxis":"x","y":[171036.21260172414],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"State=%{x}\u003cbr\u003eHome_Price=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"KS","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"KS","offsetgroup":"KS","orientation":"v","showlegend":true,"textposition":"auto","x":["KS"],"xaxis":"x","y":[179575.8387362069],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"State=%{x}\u003cbr\u003eHome_Price=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"IA","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"IA","offsetgroup":"IA","orientation":"v","showlegend":true,"textposition":"auto","x":["IA"],"xaxis":"x","y":[181249.39009655174],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"State=%{x}\u003cbr\u003eHome_Price=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"OH","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"OH","offsetgroup":"OH","orientation":"v","showlegend":true,"textposition":"auto","x":["OH"],"xaxis":"x","y":[181605.02386896554],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"State=%{x}\u003cbr\u003eHome_Price=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"AL","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"AL","offsetgroup":"AL","orientation":"v","showlegend":true,"textposition":"auto","x":["AL"],"xaxis":"x","y":[188772.70798620692],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"State=%{x}\u003cbr\u003eHome_Price=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"IN","marker":{"color":"#FECB52","pattern":{"shape":""}},"name":"IN","offsetgroup":"IN", ...

# %%
# Calculate average prices by state
avg_prices = df_home_price.groupby('State')['Home_Price'].mean().reset_index()

# Select the top 5 states based on average home prices
top_5_states = avg_prices.nlargest(5, 'Home_Price')['State']

# Filter the original dataframe to include only data for the top 5 states
df_top_5 = df_home_price[df_home_price['State'].isin(top_5_states)]

# Create a scatter plot for the top 5 states
fig7 = px.scatter(df_top_5, x='Date', y='Home_Price', color='State', title='Top 5 States: Home Prices vs. Time')
fig7.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="1d90f843-6d69-4272-a447-af4ea20fc399" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1d90f843-6d69-4272-a447-af4ea20fc399")) {                    Plotly.newPlot(                        "1d90f843-6d69-4272-a447-af4ea20fc399",                        [{"hovertemplate":"State=CA\u003cbr\u003eDate=%{x}\u003cbr\u003eHome_Price=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"CA","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"CA","orientation":"v","showlegend":true,"x":["2019-01-31T00:00:00","2019-02-28T00:00:00","2019-03-31T00:00:00","2019-04-30T00:00:00","2019-05-31T00:00:00","2019-06-30T00:00:00","2019-07-31T00:00:00","2019-08-31T00:00:00","2019-09-30T00:00:00","2019-10-31T00:00:00","2019-11-30T00:00:00","2019-12-31T00:00:00","2020-01-31T00:00:00","2020-02-29T00:00:00","2020-03-31T00:00:00","2020-04-30T00:00:00","2020-05-31T00:00:00","2020-06-30T00:00:00","2020-07-31T00:00:00","2020-08-31T00:00:00","2020-09-30T00:00:00","2020-10-31T00:00:00","2020-11-30T00:00:00","2020-12-31T00:00:00","2021-01-31T00:00:00","2021-02-28T00:00:00","2021-03-31T00:00:00","2021-04-30T00:00:00","2021-05-31T00:00:00","2021-06-30T00:00:00","2021-07-31T00:00:00","2021-08-31T00:00:00","2021-09-30T00:00:00","2021-10-31T00:00:00","2021-11-30T00:00:00","2021-12-31T00:00:00","2022-01-31T00:00:00","2022-02-28T00:00:00","2022-03-31T00:00:00","2022-04-30T00:00:00","2022-05-31T00:00:00","2022-06-30T00:00:00","2022-07-31T00:00:00","2022-08-31T00:00:00","2022-09-30T00:00:00","2022-10-31T00:00:00","2022-11-30T00:00:00","2022-12-31T00:00:00","2023-01-31T00:00:00","2023-02-28T00:00:00","2023-03-31T00:00:00","2023-04-30T00:00:00","2023-05-31T00:00:00","2023-06-30T00:00:00","2023-07-31T00:00:00","2023-08-31T00:00:00","2023-09-30T00:00:00","2023-10-31T00:00:00"],"xaxis":"x","y":[536558.0937,534955.2156,533139.16,532096.8371,531472.8461,531088.0534,531492.4151,533183.5705,535768.5643,538815.7171,542133.4526,545571.9,548380.2719,550638.7685,552814.724,554823.9813,555077.7502,553875.5467,553720.4079,556953.4557,564130.9435,573347.3342,584079.3371,594784.1325,603673.2415,611278.633,618168.4887,627188.2253,637988.8119,649585.0525,660065.983,667317.2691,672234.2797,676623.9146,682411.741,689546.8202,699497.4894,712266.3903,727663.6317,741665.551,752219.9463,757831.5391,758138.2191,753511.9944,746113.0236,739452.1413,734217.6193,729730.6957,722749.9929,715573.2733,710294.099,709712.5719,712674.4291,717861.2567,724853.1437,732764.7543,740325.1275,746472.6191],"yaxis":"y","type":"scatter"},{"hovertemplate":"State=WA\u003cbr\u003eDate=%{x}\u003cbr\u003eHome_Price=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"WA","marker":{"color":"#EF553B","symbol":"circle"},"mode":"markers","name":"WA","orientation":"v","showlegend":true,"x":["2019-01-31T00:00:00","2019-02-28T00:00:00","2019-03-31T00:00:00","2019-04-30T00:00:00","2019-05-31T00:00:00","2019-06-30T00:00:00","2019-07-31T00:00:00","2019-08-31T00:00:00","2019-09-30T00:00:00","2019-10-31T00:00:00","2019-11-30T00:00:00","2019-12-31T00:00:00","2020-01-31T00:00:00","2020-02-29T00:00:00","2020-03-31T00:00:00","2020-04-30T00:00:00","2020-05-31T00:00:00","2020-06-30T00:00:00","2020-07-31T00:00:00","2020-08-31T00:00:00","2020-09-30T00:00:00","2020-10-31T00:00:00","2020-11-30T00:00:00","2020-12-31T00:00:00","2021-01-31T00:00:00","2021-02-28T00:00:00","2021-03-31T00:00:00","2021-04-30T00:00:00","2021-05-31T00:00:00","2021-06-30T00:00:00","2021-07-31T00:00:00","2021-08-31T00:00:00","2021-09-30T00:00:00","2021-10-31T00:00:00","2021-11-30T00:00:00","2021-12-31T00:00:00","2022-01-31T00:00:00","2022-02-28T00:00:00","2022-03-31T00:00:00","2022-04-30T00:00:00","2022-05-31T00:00:00","2022-06-30T ...

# %%
# Calculate median home prices by state
median_prices = df_home_price.groupby('State')['Home_Price'].median().reset_index()

# Sort the median_prices DataFrame by 'Home_Price'
median_prices_sorted = median_prices.sort_values(by='Home_Price')

# Create a list of states sorted by median home prices
sorted_states = median_prices_sorted['State'].tolist()

# Reorder the 'State' column in the original DataFrame based on sorted_states
df_home_price['State'] = pd.Categorical(df_home_price['State'], categories=sorted_states, ordered=True)

fig8 = px.box(df_home_price, x='State', y='Home_Price', color='State',title='Distribution of Home Prices Across States')
fig8.update_xaxes(categoryorder='array', categoryarray=sorted_states)
fig8.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="98f1db27-ccac-49ba-9a4b-bdc3ca4b6a2a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("98f1db27-ccac-49ba-9a4b-bdc3ca4b6a2a")) {                    Plotly.newPlot(                        "98f1db27-ccac-49ba-9a4b-bdc3ca4b6a2a",                        [{"alignmentgroup":"True","hovertemplate":"State=%{x}\u003cbr\u003eHome_Price=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"CA","marker":{"color":"#636efa"},"name":"CA","notched":false,"offsetgroup":"CA","orientation":"v","showlegend":true,"x":["CA","CA","CA","CA","CA","CA","CA","CA","CA","CA","CA","CA","CA","CA","CA","CA","CA","CA","CA","CA","CA","CA","CA","CA","CA","CA","CA","CA","CA","CA","CA","CA","CA","CA","CA","CA","CA","CA","CA","CA","CA","CA","CA","CA","CA","CA","CA","CA","CA","CA","CA","CA","CA","CA","CA","CA","CA","CA"],"x0":" ","xaxis":"x","y":[536558.0937,534955.2156,533139.16,532096.8371,531472.8461,531088.0534,531492.4151,533183.5705,535768.5643,538815.7171,542133.4526,545571.9,548380.2719,550638.7685,552814.724,554823.9813,555077.7502,553875.5467,553720.4079,556953.4557,564130.9435,573347.3342,584079.3371,594784.1325,603673.2415,611278.633,618168.4887,627188.2253,637988.8119,649585.0525,660065.983,667317.2691,672234.2797,676623.9146,682411.741,689546.8202,699497.4894,712266.3903,727663.6317,741665.551,752219.9463,757831.5391,758138.2191,753511.9944,746113.0236,739452.1413,734217.6193,729730.6957,722749.9929,715573.2733,710294.099,709712.5719,712674.4291,717861.2567,724853.1437,732764.7543,740325.1275,746472.6191],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"State=%{x}\u003cbr\u003eHome_Price=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"TX","marker":{"color":"#EF553B"},"name":"TX","notched":false,"offsetgroup":"TX","orientation":"v","showlegend":true,"x":["TX","TX","TX","TX","TX","TX","TX","TX","TX","TX","TX","TX","TX","TX","TX","TX","TX","TX","TX","TX","TX","TX","TX","TX","TX","TX","TX","TX","TX","TX","TX","TX","TX","TX","TX","TX","TX","TX","TX","TX","TX","TX","TX","TX","TX","TX","TX","TX","TX","TX","TX","TX","TX","TX","TX","TX","TX","TX"],"x0":" ","xaxis":"x","y":[204267.2758,205004.7303,205642.74,206181.5683,206665.7463,207135.4523,207633.8119,208231.1536,208883.8822,209757.6835,210792.2979,211918.8525,213062.58,214169.0687,215248.1864,216026.1247,216303.9048,216470.1673,217120.1035,218531.9539,220663.252,223068.6583,225811.9433,228469.8056,231260.0388,234232.1185,237597.1439,241331.5411,245605.1804,250177.7166,254372.6087,257570.305,259907.8973,262332.7371,265472.2396,269081.0048,273828.8448,279138.9665,285143.4541,290969.1655,296323.9334,300997.7255,303839.6128,304731.7547,304074.0584,303133.6734,302141.7192,300867.1218,299185.3728,297586.1193,296518.713,296150.3717,296468.6271,297294.3816,298038.0489,298615.1433,298652.9011,298423.7317],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"State=%{x}\u003cbr\u003eHome_Price=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"FL","marker":{"color":"#00cc96"},"name":"FL","notched":false,"offsetgroup":"FL","orientation":"v","showlegend":true,"x":["FL","FL","FL","FL","FL","FL","FL","FL","FL","FL","FL","FL","FL","FL","FL","FL","FL","FL","FL","FL","FL","FL","FL","FL","FL","FL","FL","FL","FL","FL","FL","FL","FL","FL","FL","FL","FL","FL","FL","FL","FL","FL","FL","FL","FL","FL","FL","FL","FL","FL","FL","FL","FL","FL","FL","FL","FL","FL"],"x0":" ","xaxis":"x","y":[237695.0638,238760.268,239480.5717,240000.6757,240280.2176,240685.2159,241208.8848,241923.0596,242633.0363,243573.882,244860.741,246446.6881,248368.1268,250178.3745,251768.8194,252736.2209,253003.0139,253136.7924,253708.206,255283.3302,257809.5987,260798.9776,26 ...

# %% [markdown]
# # Home Price Visualizations embedding

# %%
fh = open('choropleth.html', 'w')
fh.close()

# %%
pio.write_html(fig5, file='choropleth.html',
               auto_open=True,
               full_html=False)

# %%
fh = open('bar.html', 'w')
fh.close()

# %%
pio.write_html(fig6, file='bar.html',
               auto_open=True,
               full_html=False)

# %%
fh = open('box.html', 'w')
fh.close()

# %%
pio.write_html(fig8, file='box.html',
               auto_open=True,
               full_html=False)

# %%
fh = open('hp_time.html', 'w')
fh.close()

# %%
pio.write_html(fig7, file='hp_time.html',
               auto_open=True,
               full_html=False)
